# %%
import xarray

# %%
aws_cmip6_root = ' s3://cmip6-pds'
project_version = 'CMIP6'
mip_name = 'CMIP'
modelling_centre = 'MOHC'
model_name = 'HadGEM3-GC31-LL'
mip_scenario = '1pctCO2'
ens_member = 'r1i1p1f3'
var_cat = 'Amon'
var_name = 'tas'

# %%
cmip6_path = f's3://cmip6-pds/{project_version}/{mip_name}/{modelling_centre}/{model_name}/{mip_scenario}/{ens_member}/{var_cat}/{var_name}/gn/v20190620'
cmip6_path
# Out:
# 's3://cmip6-pds/CMIP6/CMIP/MOHC/HadGEM3-GC31-LL/1pctCO2/r1i1p1f3/Amon/tas/gn/v20190620'

# %%
mohc_tas_ds = xarray.open_zarr(
    cmip6_path,
    storage_options={"anon": True}, 
)

# %%
mohc_tas_ds
# Out:
# <xarray.Dataset> Size: 199MB
# Dimensions:    (time: 1800, lat: 144, lon: 192, bnds: 2)
# Coordinates:
#   * time       (time) object 14kB 1850-01-16 00:00:00 ... 1999-12-16 00:00:00
#   * lat        (lat) float64 1kB -89.38 -88.12 -86.88 ... 86.88 88.12 89.38
#   * lon        (lon) float64 2kB 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#     lat_bnds   (lat, bnds) float64 2kB dask.array<chunksize=(144, 2), meta=np.ndarray>
#     lon_bnds   (lon, bnds) float64 3kB dask.array<chunksize=(192, 2), meta=np.ndarray>
#     time_bnds  (time, bnds) object 29kB dask.array<chunksize=(1800, 2), meta=np.ndarray>
#     height     float64 8B ...
# Dimensions without coordinates: bnds
# Data variables:
#     tas        (time, lat, lon) float32 199MB dask.array<chunksize=(600, 144, 192), meta=np.ndarray>
# Attributes: (12/49)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
# ...

# %%
mohc_tas_ds.time
# Out:
# <xarray.DataArray 'time' (time: 1800)> Size: 14kB
# array([cftime.Datetime360Day(1850, 1, 16, 0, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(1850, 2, 16, 0, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(1850, 3, 16, 0, 0, 0, 0, has_year_zero=True), ...,
#        cftime.Datetime360Day(1999, 10, 16, 0, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(1999, 11, 16, 0, 0, 0, 0, has_year_zero=True),
#        cftime.Datetime360Day(1999, 12, 16, 0, 0, 0, 0, has_year_zero=True)],
#       shape=(1800,), dtype=object)
# Coordinates:
#   * time     (time) object 14kB 1850-01-16 00:00:00 ... 1999-12-16 00:00:00
#     height   float64 8B ...
# Attributes:
#     axis:           T
#     bounds:         time_bnds
#     long_name:      time
#     standard_name:  time

# %%
mohc_tas_ds.sel({'time': '1995-06-16'}).
# Out:
# <xarray.Dataset> Size: 119kB
# Dimensions:    (time: 1, lat: 144, lon: 192, bnds: 2)
# Coordinates:
#   * time       (time) object 8B 1995-06-16 00:00:00
#   * lat        (lat) float64 1kB -89.38 -88.12 -86.88 ... 86.88 88.12 89.38
#   * lon        (lon) float64 2kB 0.9375 2.812 4.688 6.562 ... 355.3 357.2 359.1
#     lat_bnds   (lat, bnds) float64 2kB dask.array<chunksize=(144, 2), meta=np.ndarray>
#     lon_bnds   (lon, bnds) float64 3kB dask.array<chunksize=(192, 2), meta=np.ndarray>
#     time_bnds  (time, bnds) object 16B dask.array<chunksize=(1, 2), meta=np.ndarray>
#     height     float64 8B ...
# Dimensions without coordinates: bnds
# Data variables:
#     tas        (time, lat, lon) float32 111kB dask.array<chunksize=(1, 144, 192), meta=np.ndarray>
# Attributes: (12/49)
#     Conventions:            CF-1.7 CMIP-6.2
#     activity_id:            CMIP
#     branch_method:          standard
#     branch_time_in_child:   0.0
#     branch_time_in_parent:  0.0
# ...
